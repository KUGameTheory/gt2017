# %% [markdown]
# # Solution Extra Exercise

# %% [markdown]
# M2 is strictly dominated by a mix putting $\alpha$ on U and $(1-\alpha)$ on D if the mix does strictly better against both L and R, that is if
# $$\alpha e^{3r}+(1-\alpha) e^0>e^{2.6r}$$
# and
# $$\alpha e^0+(1-\alpha)e^{3r}>e^{0.5r}.$$
# To achieve this, note that the second inequality is in a sense easier to achieve. To find the critical $r$, we will therefore choose $\alpha$ such that it is satisfied with equality. That is, we take
# $$\alpha=\frac{e^{0.5r}-e^{3r}}{1-e^{3r}}.$$
# Plugging this \alpha into the first inequality, we solve for the critical $r$ by solving this inequality (with equality); that is we solve
# $$\frac{e^{0.5r}-e^{3r}}{1-e^{3r}} e^{3r}+\left(1-\frac{e^{0.5r}-e^{3r}}{1-e^{3r}}\right) 1-e^{2.6r}=0.$$
# I plot the left hand side as a function of $r$ below and calculate where it is equal to zero.

# %%
using Plots
using Roots

f(r)=(e^(0.5r)-e^(3r))/(1-e^(3r))*e^(3r)+(1-(e^(0.5r)-e^(3r))/(1-e^(3r)))-e^(2.6r)

println("Critical r is ", fzero(f,[0.01,0.1]))

plot(0.01:0.001:0.15,f)
# Out:
# Critical r is 0.08751853869308206
# <script src="/home/christoph/.julia/v0.6/Plots/src/backends/../../deps/plotly-latest.min.js"></script>    <div id="5a038848-b698-48f9-a3b0-296fd92a02ad" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('5a038848-b698-48f9-a3b0-296fd92a02ad');
#     Plotly.plot(PLOT, [{"showlegend":true,"mode":"lines","xaxis":"x","colorbar":{"title":""},"line":{"color":"rgba(0, 154, 250, 1.000)","shape":"linear","dash":"solid","width":1},"y":[-0.0008989353793260602,-0.0009775205063595749,-0.001054011181526704,-0.0011283976922349392,-0.0012006702891318444,-0.0012708191859747142,-0.001338834559501123,-0.0014047065492976962,-0.001468425257670214,-0.001529980749512383,-0.001589363052173054,-0.0016465621553256593,-0.0017015680108329878,-0.0017543705326181769,-0.0018049595965268228,-0.0018533250401955303,-0.0018994566629175758,-0.0019433442255067934,-0.001984977450163239,-0.0020243460203368535,-0.002061439580591573,-0.0020962477364687704,-0.0021287600543486995,-0.0021589660613148265,-0.0021868552450148293,-0.002212417053522042,-0.0022356408951957896,-0.002256516138543496,-0.002275032112079023,-0.0022911781041832224,-0.002304943362962497,-0.0023163170961082447,-0.002325288470753639,-0.002331846613332633,-0.0023359806094356284,-0.002337679503668255,-0.0023369322995054898,-0.002333727959148435,-0.0023280554033791034,-0.002319903511416088,-0.0023092611207675695,-0.0022961170270856535,-0.0022804599840196005,-0.002262278703068832,-0.002241561853434604,-0.00221829806187257,-0.0021924759125431237,-0.002164083946862627,-0.0021331106633548647,-0.002099544517498053,-0.0020633739215756286,-0.002024587244527698,-0.0019831728117929437,-0.001939118905162962,-0.0018924137626255,-0.0018430455782110222,-0.001791002501